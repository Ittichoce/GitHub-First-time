# %% [markdown]
# <a href="https://colab.research.google.com/github/Ittichoce/Test/blob/main/1_My_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My first notebook**
#
# This is **Markdown Cell**. We can *format* our content. Even write a list.
# - Item 1
# - Item 2

# %%
print("I will be writing python very soon!!!")
# Out:
# I will be writing python very soon!!!

# %%
a = 2
b = 3 
print(a*b)
# Out:
# 6

# %% [markdown]
# ---

# %% [markdown]
# ![00.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![01.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![02.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![03.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![04.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **This is my notebook for practice python on cloud platform.**
#
# ---
